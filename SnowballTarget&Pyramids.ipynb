# %%
# Clone the repository
# !git clone --depth 1 https://github.com/Unity-Technologies/ml-agents
# Out:
# fatal: destination path 'ml-agents' already exists and is not an empty directory.

# %%
# Go inside the repository and install the package
# %cd ml-agents
# !pip install -e ./ml-agents-envs
# !pip install -e ./ml-agents
# Out:
# /content/ml-agents
# Obtaining file:///content/ml-agents/ml-agents-envs
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: mlagents-envs
#     Found existing installation: mlagents-envs 1.1.0.dev0
#     Uninstalling mlagents-envs-1.1.0.dev0:
#       Successfully uninstalled mlagents-envs-1.1.0.dev0
#   Running setup.py develop for mlagents-envs
# ...
# Obtaining file:///content/ml-agents/ml-agents
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached onnx-1.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.7 MB)
# ...
#   Using cached cattrs-1.5.0-py3-none-any.whl (19 kB)
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...

# %%
# !mkdir ./training-envs-executables
# !mkdir ./training-envs-executables/linux

# %%
# !wget "https://github.com/huggingface/Snowball-Target/raw/main/SnowballTarget.zip" -O ./training-envs-executables/linux/SnowballTarget.zip
# Out:
# --2024-07-21 13:49:03--  https://github.com/huggingface/Snowball-Target/raw/main/SnowballTarget.zip
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://media.githubusercontent.com/media/huggingface/Snowball-Target/main/SnowballTarget.zip [following]
# --2024-07-21 13:49:03--  https://media.githubusercontent.com/media/huggingface/Snowball-Target/main/SnowballTarget.zip
# Resolving media.githubusercontent.com (media.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to media.githubusercontent.com (media.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35134213 (34M) [application/zip]
# Saving to: ‘./training-envs-executables/linux/SnowballTarget.zip’
#
# ./training-envs-exe 100%[===================>]  33.51M  --.-KB/s    in 0.1s
#
# ...

# %%
# !unzip -d ./training-envs-executables/linux/ ./training-envs-executables/linux/SnowballTarget.zip
# Out:
# Archive:  ./training-envs-executables/linux/SnowballTarget.zip
#    creating: ./training-envs-executables/linux/SnowballTarget/
#   inflating: ./training-envs-executables/linux/SnowballTarget/SnowballTarget.x86_64
#    creating: ./training-envs-executables/linux/SnowballTarget/SnowballTarget_BurstDebugInformation_DoNotShip/
#    creating: ./training-envs-executables/linux/SnowballTarget/SnowballTarget_BurstDebugInformation_DoNotShip/Data/
#    creating: ./training-envs-executables/linux/SnowballTarget/SnowballTarget_BurstDebugInformation_DoNotShip/Data/Plugins/
#   inflating: ./training-envs-executables/linux/SnowballTarget/SnowballTarget_BurstDebugInformation_DoNotShip/Data/Plugins/lib_burst_generated.txt
#    creating: ./training-envs-executables/linux/SnowballTarget/SnowballTarget_Data/
#   inflating: ./training-envs-executables/linux/SnowballTarget/SnowballTarget_Data/app.info
#   inflating: ./training-envs-executables/linux/SnowballTarget/SnowballTarget_Data/boot.config
# ...

# %%
# !chmod -R 755 ./training-envs-executables/linux/SnowballTarget

# %%
# !mlagents-learn ./config/ppo/SnowballTarget.yaml --env=./training-envs-executables/linux/SnowballTarget/SnowballTarget --run-id="SnowballTarget1" --no-graphics
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py:749: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:431.)
#   _C._set_default_tensor_type(t)
# 2024-07-21 13:50:48.864924: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-21 13:50:48.864973: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-21 13:50:48.866798: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
# !mlagents-push-to-hf --run-id="SnowballTarget1" --local-dir="./results/SnowballTarget1" --repo-id="nithin04/ppo-SnowballTarget" --commit-message="First Push"
# Out:
# [INFO] This function will create a model card and upload your SnowballTarget1 into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# [INFO] Pushing repo SnowballTarget1 to the Hugging Face Hub
# SnowballTarget-199984.pt:   0% 0.00/3.85M [00:00<?, ?B/s]
# Upload 13 LFS files:   0% 0/13 [00:00<?, ?it/s]
#
# SnowballTarget-149984.onnx:   0% 0.00/651k [00:00<?, ?B/s]
#
#
# SnowballTarget.onnx:   0% 0.00/651k [00:00<?, ?B/s]
#
#
#
# SnowballTarget-149984.pt:   0% 0.00/3.85M [00:00<?, ?B/s]
#
#
#
#
# SnowballTarget.onnx:   0% 0.00/651k [00:00<?, ?B/s]
#
# SnowballTarget-199984.pt:   0% 16.4k/3.85M [00:00<00:55, 69.5kB/s]
#
#
#
#
# SnowballTarget.onnx:   3% 16.4k/651k [00:00<00:09, 70.1kB/s]
#
#
#
# SnowballTarget-149984.pt:   0% 16.4k/3.85M [00:00<00:55, 68.6kB/s]
#
#
# SnowballTarget-149984.onnx: 100% 651k/651k [00:00<00:00, 1.02MB/s]
# SnowballTarget.onnx: 100% 651k/651k [00:00<00:00, 935kB/s]
# ...

# %%
# !wget "https://huggingface.co/spaces/unity/ML-Agents-Pyramids/resolve/main/Pyramids.zip" -O ./training-envs-executables/linux/Pyramids.zip
# Out:
# --2024-07-21 14:01:27--  https://huggingface.co/spaces/unity/ML-Agents-Pyramids/resolve/main/Pyramids.zip
# Resolving huggingface.co (huggingface.co)... 18.164.174.17, 18.164.174.118, 18.164.174.55, ...
# Connecting to huggingface.co (huggingface.co)|18.164.174.17|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# %%capture
# !unzip -d ./training-envs-executables/linux/ ./training-envs-executables/linux/Pyramids.zip

# %%
# !chmod -R 755 ./training-envs-executables/linux/Pyramids/Pyramids

# %%
# !mlagents-learn ./config/ppo/PyramidsRND.yaml --env=./training-envs-executables/linux/Pyramids/Pyramids --run-id="Pyramids Training new" --no-graphics
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py:749: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:431.)
#   _C._set_default_tensor_type(t)
# 2024-07-21 14:03:17.451447: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-21 14:03:17.451504: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-21 14:03:17.452737: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !mlagents-push-to-hf --run-id="Pyramids Training new" --local-dir="./results/Pyramids Training new" --repo-id="nithin04/ppo-PyramidsTarget" --commit-message="First Push"
# Out:
# [INFO] This function will create a model card and upload your Pyramids Training new into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# [INFO] Pushing repo Pyramids Training new to the Hugging Face Hub
# Pyramids.onnx:   0% 0.00/1.42M [00:00<?, ?B/s]
# Pyramids-499872.onnx:   0% 0.00/1.42M [00:00<?, ?B/s]
#
# Pyramids-1000039.pt:   0% 0.00/8.66M [00:00<?, ?B/s]
#
#
# Pyramids-499872.pt:   0% 0.00/8.66M [00:00<?, ?B/s]
#
#
#
# Upload 9 LFS files:   0% 0/9 [00:00<?, ?it/s]
#
#
#
#
# Pyramids.onnx:   0% 0.00/1.42M [00:00<?, ?B/s]
#
# Pyramids-1000039.pt:   0% 16.4k/8.66M [00:00<03:27, 41.6kB/s]
#
#
# Pyramids.onnx:   1% 16.4k/1.42M [00:00<00:35, 40.0kB/s]
#
#
#
#
# Pyramids.onnx:   1% 16.4k/1.42M [00:00<00:34, 41.1kB/s]
# Pyramids-499872.onnx:   1% 16.4k/1.42M [00:00<00:35, 39.6kB/s]
#
# Pyramids-1000039.pt:  60% 5.23M/8.66M [00:00<00:00, 13.9MB/s]
#
#
# Pyramids-499872.pt:  50% 4.34M/8.66M [00:00<00:00, 11.1MB/s]
#
#
# ...
